# %% [markdown]
# ## 例題２
#
#
# Q.解明しようしている材料問題（仮想問題）が何か？
#
# A. ReCo (希土類元素ーコバルト）規則合金のキュリー温度回帰の予測能を評価する。
#
# A. 線形回帰を通して線形回帰での重要な説明変数を評価する。
#
#
# Q. データがどうようなものか？
#
# A. 希土類元素説明変数、構造説明変数
#
# A. キュリー温度
#
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. 線形回帰、LASSO、カーネルリッジ回帰を行う。
#
# A. 線形回帰では回帰係数の評価を行う。

# %% [markdown]
# **解析例**
# ![LassoCVのハイパーパラメタ依存性](image_keep/LassoCV_boxplot.png)
# ![目的変数値とLasso CV(test)の予測値](image_keep/LassoCV_y_yCVtest.png)
