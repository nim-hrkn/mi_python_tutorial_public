# %% [markdown]
# ## GAN, cGAN
#
# 画像（文字）生成モデルの作成
#
# ### 例題
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. GAN，cGANを作成する．
#
# Q. データがどうようなものか？
#
# A. scikit-learn内蔵数字データ
#
# Q. どのような手法で何を抽出しようとするか？
#
# A.
#   - 畳み込みニューラルネットワークモデル
#   - 大規模言語モデルを用いた知識取得を行う．

# %% [markdown]
# ### ファイル
#
# - 8100.0050.introduction.ipynb このファイル
# - 8100.0101.GAN_v2.ipynb　GANの説明
# - 8100.0200.cGAN-steps1-2.ipynb cGANの説明step 1, step2
# - 8100.0210.cGAN-step3.ipynb cGANの説明 step 3
# - 8100.9000.BCE_loss.ipynb torchのBCE lossについて
# - 8100.9100.filter_vis.ipynb　使用したニューラルネットワークの詳細
