# %% [markdown]
# ## デノイズ
#
# ニューラルネットワークモデルの例としてデノイズを行う．
#
#
# ### 例題
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. ニューラルネットワークモデルを用いてデノイズを行う．
#
# Q. データがどうようなものか？
#
# A. TEMの生成AI画像．JAIST Dam Hieu Chi教授のご好意による．
#
# Q. どのような手法で何を抽出しようとするか？
#
# A.
#   - ニューラルネットワークモデルでautoencoderを使う．
#   - Pytorchの使い方を学ぶ．
#   - 大規模言語モデルを用いた知識取得を行う．

# %% [markdown]
# ### ファイル
#
# - 8001.0010.contents.ipynb このファイル．
# - 8001.0052.explanation.ipynb　説明．
# - 8001.0500.add_noise.ipynb　デノイズデータ作成スクリプト．
# cropped_64x64/からcropped_64x64_permilX/を作成する．
# - 8001.1000.denoise_code.ipynb　デノイズコード本体．
# - 8001.1500.filter_vis.ipynb ニューラルネットワークモデルのフィルター重みを表示するコード．
# - 8001.2000.median_filter.ipynb　（参考）メディアンフィルターコード．
