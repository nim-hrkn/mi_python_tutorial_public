# %% [markdown]
# ## scipy,scikit-learnクラスの説明
#
# 以下ではクラスター数を３としています。
#
# * Kmeans
#
# ```python
# from sklearn.cluster import KMeans
# km = KMeans(n_clusters=3)
# km.fit(X)
# yp_km = km.predict(X)
# ```
#
# * ガウス混合法
#
# ```python
# from sklearn.mixture import GaussianMixture
# gmm = GaussianMixture(n_components=3)
# gmm.fit(X)
# yp_gmm = gmm.predict(X)
# yproba_gmm = gmm.predict_proba(X)
# ```

# %% [markdown]
# * 階層クラスタリング
#
#
# ```python
# from scipy.cluster.hierarchy import dendrogram, linkage
#
# Z = linkage(X)
# dendrogram(Z)
# ```

# %% [markdown]
# 次の例はdata説明時に用いた、階層クラスタリングのより一般的な形です。
#
# ```python
# X = scaler.fit_transform(Xraw)
# df_tmp = pd.DataFrame(X)
# corr = 1- np.abs(df_tmp.corr()) # Pearson's correlation
# pairdistance = squareform(corr) # linkage()に与える一次元型へ変換する。
# Z = linkage(pairdistance)
# ```
