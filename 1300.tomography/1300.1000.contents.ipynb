# %% [markdown]
# ## 例題
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 並行トモグラフィ像の再構成を行う。
#
# Q. データがどうようなものか？
#
# A. 説明変数 :　トモフラフィ像イメージ
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. スパースモデリング（LASSO）による元画像の再構成

# %% [markdown]
# **解析例**
#
# ![元画像（左）とトモグラフ撮影を行った後にLassoにより復元された画像(右）](image_keep/letter_l1_reconstructed.png)
