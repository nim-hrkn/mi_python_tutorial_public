# %% [markdown]
# ## Appendix
#
# * "Bayesian spectroscopy in solid-state photo-physics",
# Ichiro Akai, Kazuori Iwamitsu, Masato Okada,
# IOP Conf. Series: Journal of Physics: Conf. Series 1036 (2018) 012022,
# DOI: 10.1088/1742-6596/1036/1/012022
