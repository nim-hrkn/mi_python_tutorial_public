# %% [markdown]
# ## 例題
#
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 関連性探索を行って、元素間の規則を探索する。
#
# Q. データがどうようなものか？
#
# A. pymatgen.core.periodic_table.Elementの
# 元素の説明変数を全て用いる。
#
# (全ての元素に対して値があるわけではない。)
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. 各元素は定性的、定量的に特徴量を持っているのでそれらをtransactionに変換して関連性探索を行う。
#
#
# A. 頻出データマイニングにより相関ルールを求める。

# %% [markdown]
# thermal_conductivityが高いという条件に対する規則がelectrical_resistivityが低いことという
# Wiedemann–Franz lawを得る。ただし、図を見るとわかるとおり金属の場合について成り立つ法則である。
# ![thermal_conductivity vs electrical_resistivity](image_keep/atom_resistivity_vs_thermal_conductivity.png)
