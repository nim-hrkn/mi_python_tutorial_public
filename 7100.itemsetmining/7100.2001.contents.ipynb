# %% [markdown]
# ## 例題
#
# →7100.2200.hea4_R_itemsetmining.ipynb
#
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 関連性探索を行って、電気伝導の規則を探索する。
#
# Q. データがどうようなものか？
#
#
# A. 四元系固溶体の残留電気伝導度
#
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. 頻出データマイニングにより相関ルールを求める。

# %% [markdown]
# ### 例
#
# ![R最も大きな区画で多く現れる特徴量](image_keep/itemset_id10.png)
