# %% [markdown]
# ## 例題１
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. ReCo (希土類元素ーコバルト）規則合金のキュリー温度回帰の予測能を評価する。
#
# A. 重要な説明変数を評価する。
#
# Q. データがどうようなものか？
#
# A. 説明変数 : 希土類元素説明変数、構造説明変数
#
# A. 目的変数 : キュリー温度
#
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. 説明変数組み合わせに対して全探索を行う。

# %% [markdown]
# **解析結果**
#
# ![全探索によるR2に対するDOS](image_keep/ReCo_ES_score_vs_DOS.png)
#
# ![R2が高い順に並べた線形回帰係数の絶対値](image_keep/ReCo_ES_index_vs_abscoef.png)
