# %% [markdown]
# ## 例題２
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 炭素８原子による構造データの次元圧縮を行い視覚的に分類が可能かを確認する。
#
# Q. データがどうようなものか？
#
# A. GRRM法（北大前田理教授）により構造探索を行った炭素８原子による構造をBehlerの二体symmetry functionによる変換した量を説明変数とする。
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. PCA,manifold learningによる次元圧縮

# %% [markdown]
# **解析例**
#
# ![](image_keep/PCA_carbon_atomic_environment.png)
