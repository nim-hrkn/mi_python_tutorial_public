# %% [markdown]
# ## 例題１
#
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 目的変数変化がPCAなどの次元圧縮で必ずしも長軸方向にならないことを理解する。
# A. 次元圧縮された長軸方向は解析者が得たデータの都合で決まることもあることを理解する。
#
# Q. データがどうようなものか？
#
# A. 簡単な二次元データ
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. PCAによる次元圧縮
