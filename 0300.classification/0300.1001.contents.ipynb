# %% [markdown]
# ## 例題１
#
# 閃亜鉛鉱構造構造とウルツ鉱構造の分類
#
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 閃亜鉛鉱構造構造とウルツ鉱構造でどちらが安定なのかを機械学習で予測する。
#
# Q. データがどうようなものか？
#
# A. 説明変数：それぞれの構成元素の特徴量
#
# A. 目的変数：第一原理計算での安定構造
#
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. logistic regressionによりclassificationを行う。

# %% [markdown]
# **解析例**
#
# ![分類スコアのハイパーパラメタ依存性](image_keep/ZB_WZ_cls_boxplot.png)
#
# classification report
# ```
#     precision    recall  f1-score   support
#
#        False       1.00      0.95      0.97        41
#         True       0.95      1.00      0.98        41
#
#     accuracy                           0.98        82
#    macro avg       0.98      0.98      0.98        82
# weighted avg       0.98      0.98      0.98        82
# ```
