# %% [markdown]
# # Contents
#
# Copyright (c) 2017-2023, Hiori Kino
#
# All rights reserved.
#
# This software is released under the BSD License (3-clause BSD License).
#
# このハンズオンの構成は以下のようになっています。
#
# ## 座学、基礎編
#
# ###  0010.introduction
#
# 機械学習の座学
#
# ### 0070.explain_data
#
# 使用するデータの説明
#
#
# ## 実習、基礎編
#
# ### 0100.regression
#
# 回帰
#
# ### 0200.dimentionality_reduction
#
# 次元圧縮
#
# ### 0300.classification
#
# 分類
#
# ### 0400.clustering
#
# クラスタリング
#
# ## 実習、応用編
#
# ### 1150.hea4_dos_clustering
#
# 一次元ベクトルに対して次元圧縮と分類を行う。
#
# ### 1300.tomography
#
# L1最適化を用いてトモグラフィ像の再構成を行う。
#
#
# ### 2000.linear_mixture_model
# クラスタリングと回帰を結びつける。
#
#
# ### 3000.descriptor_importance
# ### 3100.exhaustive_search
#
# 回帰モデル網羅探索を行う。
#
# ### 5000.Bayesian_optimization
#
# ベイズ最適化を行う。
#
#
# ### 6000.bayesian_linear_regression
# ベイズ線形回帰を用いてモデルパラメタフィットを行う。
#
# ### 6500.pymc3_bayesian_inference
# モンテカルロ法pymc3を用いてモデルパラメタフィットを行う。
#
#
# ### 7000.recommender_system
# 推薦システムを用いて構造探索を行う。
#
#
# ### 7100.itemsetmining
# 元素データを用いてitemset miningを行う。
#
# ### 8001.denoise
# LLMを用いて学習しながら，オートエンコーダーを用いてTEM画像のデノイズを行う．
#
# ### 8100.cGAN
# LLMを用いて学習しながら，GANおよびconditional GANプログラムを作成する．
#
# ## 付録
#
# ### 9000.misc
#
# python tips, pandas, pymatgenの説明
