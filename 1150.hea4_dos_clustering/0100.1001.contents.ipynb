# %% [markdown]
# ## 例題１
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 適切な前処理を行うことで説明変数sin(x)が選択されることを確認する。
#
# Q. データがどうようなものか？
#
# A. 説明変数 : 四元固溶体のDOS
#
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. 説明変数の変換、次元圧縮を用いることにより、クラスタリングがより妥当に出来ることを示す。

# %% [markdown]
# ![加工後にt-sneを行った結果](image_keep/cluster_smearing_30_1800_True_tsne.png)
#
# 図：説明変数加工後にt-sneにより二次元にクラスタリングした結果を示す。
