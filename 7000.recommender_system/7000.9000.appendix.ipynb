# %% [markdown]
# ## Appendix
#
# * "Unsupervised word embeddings capture latent
# knowledge from materials science literature",
# Vahe tshitoyan, et al., Nature, 571, 95 (2019). DOI: 10.1038/s41586-019-1335-8
#
# - "Integrating multiple materials science projects
# in a single neural network"
# Kan Hatakeyama-Sato, Kenichi Oyaizu, Communications Materials, 1, 49 (2020).
# https://www.nature.com/articles/s43246-020-00052-8, DOI: 10.1038/s43246-020-00052-8
#
# - "Evidence-based recommender system for high-entropy alloys", Minh-Quyet Ha, et al. nature computational science, 1, 470–478 (2021). https://www.nature.com/articles/s43588-021-00097-w,
# DOI: 10.1038/s43588-021-00097-w
