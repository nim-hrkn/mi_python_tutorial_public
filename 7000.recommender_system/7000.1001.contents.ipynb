# %% [markdown]
# ## 例題
#
#
# Q. 解明しようしている材料問題（仮想問題）が何か？
#
# A. 二元元素結晶の未知構造の予測
#
# Q. データがどうようなものか？
#
# A. 説明変数：group 13-15, row3-5の二元元素結晶の組成と空間群のデータ
#
# Q. どのような手法で何を抽出しようとするか？
#
# A. 行列特異値分解による低ランク近似で協調フィルタリングを行う。

# %% [markdown]
# **解析例**
#
# 明るい色の部分が存在確率が高い。
#
# ![協調フィルタリングによる物質推薦](image_keep/recommend.png)
